# %%
import tensorflow as tf

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# ...
# 11493376/11490434 [==============================] - 1s 0us/step

# %%
model = tf.keras.models.Sequential([
  tf.keras.layers.Flatten(input_shape=(28, 28)),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dropout(0.2),
  tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)

test_loss, test_acc = model.evaluate(x_test, y_test)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 5s 78us/sample - loss: 0.0653 - accuracy: 0.9786
# Epoch 2/5
# 60000/60000 [==============================] - 5s 80us/sample - loss: 0.0563 - accuracy: 0.9820
# Epoch 3/5
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.0525 - accuracy: 0.9824
# Epoch 4/5
# 60000/60000 [==============================] - 5s 75us/sample - loss: 0.0464 - accuracy: 0.9848
# Epoch 5/5
# ...
# 10000/10000 [==============================] - 0s 35us/sample - loss: 0.0696 - accuracy: 0.9810

# %%
train_loss, train_acc = model.evaluate(x_train, y_train)
# Out:
# 60000/60000 [==============================] - 4s 68us/sample - loss: 0.0176 - accuracy: 0.9951

# %%
print(train_acc)
print(test_acc)
# Out:
# 0.9951
# 0.981

# %% [markdown]
# # Pre-trained Models

# %%
model = tf.keras.applications.MobileNetV2()
# Out:
# ...
# 14540800/14536120 [==============================] - 2s 0us/step

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

def load_image(filename):
    image = mpimg.imread(filename)
    return image

# Data pre-processing to fit model's input shape of 224x224x3
def proprocess(image):
    IMG_SIZE = 224
    image = tf.cast(image, tf.float32)
    image = (image/127.5) - 1
    image = tf.image.resize(image, (IMG_SIZE, IMG_SIZE))
    return image

# %%
img = load_image('images/doggo1.jpg')
plt.imshow(img)

# %%
img = proprocess(img)
plt.imshow(img)
# Out:
# W0329 04:28:09.292676 140412572411264 image.py:664] Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
with open('imagenet_labels.txt', 'r') as f:
    labels = np.array(f.read().splitlines())
    
print(labels[:10])
# Out:
# ['tench' 'goldfish' 'great_white_shark' 'tiger_shark' 'hammerhead'
#  'electric_ray' 'stingray' 'cock' 'hen' 'ostrich']

# %%
input_tensor = tf.expand_dims(img, 0)
input_tensor.shape
# Out:
# TensorShape([1, 224, 224, 3])

# %%
import numpy as np
probs = model.predict(input_tensor).flatten()
# Imagenet has 1000 classes
print(probs.shape)
# Out:
# (1000,)

# %%
top_probs = np.sort(probs)[::-1]
top_indices = np.argsort(probs)[::-1] # reverse it to be in descending order of probability
top_10_probs = top_probs[:10]
top_10 = labels[top_indices[:10]]

# %%
import pandas as pd
df = pd.DataFrame()
df['Label'] = top_10
df['Confidence'] = top_10_probs
df
# Out:
#                         Label  Confidence
# 0                    Pembroke    0.824145
# 1                    Cardigan    0.118465
# 2                Ibizan_hound    0.006454
# 3             German_shepherd    0.003215
# 4                       dingo    0.002971
# 5                     basenji    0.001979
# 6                      kelpie    0.001041
# 7                      basset    0.000944
# 8            Brittany_spaniel    0.000890
# 9  Greater_Swiss_Mountain_dog    0.000818
